# %% [markdown]
# <a href="https://colab.research.google.com/github/elbamoncito/elpaps/blob/master/lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <H1> PRUEBA LAB 06/08/2019</H1>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
# !pwd
# !ls
# %cd /content/drive/My Drive/IMG_PDI/
# !pwd

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread('imagenss.jpg', cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(500),int(500)))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F4897DF5400>
